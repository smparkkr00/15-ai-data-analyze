# %%
# 평균값

import pandas as pd

df = pd.read_csv(r"C:/Users/KDT34/Documents/15-data-analyze/3_데이터살펴보기/data/auto-mpg.csv", header = None)

df.columns = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model year', 'origin', 'name']

df
